# %% [markdown]
# # 결측치(Missing Value) 처리 실습 ---------------------
#
# - 결측치(Missing Value)란?
#      : 값이 들어있지 않는 것으로 NaN, NA로 표기
#
# - 관련 메서드
#     - 체크: isnull(), isna() <---> notnull(), notna()
#     - 삭제: dropna()
#     - 치환: fillna()

# %%
# 모듈 로딩
import pandas as pd

# 파일 관련 함수 선언
DIR_PATH='../DATA/'
FILE_NAME=DIR_PATH+'weather.csv'
FILE_NAME
# Out:
# '../DATA/weather.csv'

# %%
# (1) CSV FILE => DataFrame으로 로딩
weatherDF=pd.read_csv(FILE_NAME)
weatherDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 35 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       22 non-null     object
#  1   year     22 non-null     int64
#  2   month    22 non-null     int64
#  3   element  22 non-null     object
#  4   d1       2 non-null      float64
#  5   d2       4 non-null      float64
#  6   d3       4 non-null      float64
#  7   d4       2 non-null      float64
#  8   d5       8 non-null      float64
#  9   d6       2 non-null      float64
#  10  d7       2 non-null      float64
#  11  d8       2 non-null      float64
#  12  d9       0 non-null      float64
#  13  d10      2 non-null      float64
#  14  d11      2 non-null      float64
#  15  d12      0 non-null      float64
#  16  d13      2 non-null      float64
#  17  d14      4 non-null      float64
#  18  d15      2 non-null      float64
#  19  d16      2 non-null      float64
# ...

# %%
weatherDF.isnull()
# Out:
#        id   year  month  element     d1     d2     d3     d4     d5     d6  \
# 0   False  False  False    False   True   True   True   True   True   True
# 1   False  False  False    False   True   True   True   True   True   True
# 2   False  False  False    False   True  False  False   True   True   True
# 3   False  False  False    False   True  False  False   True   True   True
# 4   False  False  False    False   True   True   True   True  False   True
# 5   False  False  False    False   True   True   True   True  False   True
# 6   False  False  False    False   True   True   True   True   True   True
# 7   False  False  False    False   True   True   True   True   True   True
# 8   False  False  False    False   True   True   True   True   True   True
# 9   False  False  False    False   True   True   True   True   True   True
# 10  False  False  False    False   True   True   True   True   True   True
# ...

# %%
# 결측치 갯수 파악-------------------------------------------------------------
weatherDF.isnull().sum()
# Out:
# id          0
# year        0
# month       0
# element     0
# d1         20
# d2         18
# d3         18
# d4         20
# d5         14
# d6         20
# d7         20
# d8         20
# d9         22
# d10        20
# d11        20
# d12        22
# d13        20
# d14        18
# d15        20
# d16        20
# d17        20
# d18        22
# d19        22
# d20        22
# d21        22
# d22        22
# d23        18
# d24        22
# d25        20
# d26        20
# d27        16
# d28        20
# d29        18
# d30        20
# d31        20
# dtype: int64

# %%
weatherDF.head()
# Out:
#         id  year  month element  d1    d2    d3  d4    d5  d6  ...  d22   d23  \
# 0  MX17004  2010      1    tmax NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 1  MX17004  2010      1    tmin NaN   NaN   NaN NaN   NaN NaN  ...  NaN   NaN
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN   NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN   NaN NaN  ...  NaN  10.7
# 4  MX17004  2010      3    tmax NaN   NaN   NaN NaN  32.1 NaN  ...  NaN   NaN
#
#    d24  d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  NaN  14.5  NaN
# 2  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
# 4  NaN  NaN  NaN  NaN  NaN  NaN   NaN  NaN
#
# [5 rows x 35 columns]

# %%
# 2010년도 1월달의 (최고 온도 - 최저 온도 출력)--------------------------------
month_01 = weatherDF.iloc[[0,1]]
month_01
# Out:
#         id  year  month element  d1  d2  d3  d4  d5  d6  ...  d22  d23  d24  \
# 0  MX17004  2010      1    tmax NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
# 1  MX17004  2010      1    tmin NaN NaN NaN NaN NaN NaN  ...  NaN  NaN  NaN
#
#    d25  d26  d27  d28  d29   d30  d31
# 0  NaN  NaN  NaN  NaN  NaN  27.8  NaN
# 1  NaN  NaN  NaN  NaN  NaN  14.5  NaN
#
# [2 rows x 35 columns]

# %%
month_01.dropna(axis=1,how='all')
# Out:
#         id  year  month element   d30
# 0  MX17004  2010      1    tmax  27.8
# 1  MX17004  2010      1    tmin  14.5

# %%
# 2월의 최고-최저 온도 출력
month_02 = weatherDF.iloc[[2,3]]
month_02
# Out:
#         id  year  month element  d1    d2    d3  d4  d5  d6  ...  d22   d23  \
# 2  MX17004  2010      2    tmax NaN  27.3  24.1 NaN NaN NaN  ...  NaN  29.9
# 3  MX17004  2010      2    tmin NaN  14.4  14.4 NaN NaN NaN  ...  NaN  10.7
#
#    d24  d25  d26  d27  d28  d29  d30  d31
# 2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [2 rows x 35 columns]

# %%
month_02.dropna(axis=1,how='all')
# Out:
#         id  year  month element    d2    d3   d11   d23
# 2  MX17004  2010      2    tmax  27.3  24.1  29.7  29.9
# 3  MX17004  2010      2    tmin  14.4  14.4  13.4  10.7

# %%
# 과제0704-(1) 2010년 1월~12월까지 최고온도-최저온도 데이터 추출

# %% [markdown]
# # 처리방법 - (2) 치환

# %%
weatherDF=pd.read_csv(FILE_NAME)

# %%
weatherDF.fillna(method = 'bfill')
# Out:
#          id  year  month element    d1    d2    d3    d4    d5    d6  ...  \
# 0   MX17004  2010      1    tmax  29.9  27.3  24.1  27.2  32.1  27.8  ...
# 1   MX17004  2010      1    tmin  29.9  27.3  24.1  27.2  32.1  27.8  ...
# 2   MX17004  2010      2    tmax  29.9  27.3  24.1  27.2  32.1  27.8  ...
# 3   MX17004  2010      2    tmin  29.9  14.4  14.4  27.2  32.1  27.8  ...
# 4   MX17004  2010      3    tmax  29.9  31.3  28.6  27.2  32.1  27.8  ...
# 5   MX17004  2010      3    tmin  29.9  31.3  28.6  27.2  14.2  27.8  ...
# 6   MX17004  2010      4    tmax  29.9  31.3  28.6  27.2  29.6  27.8  ...
# 7   MX17004  2010      4    tmin  29.9  31.3  28.6  27.2  29.6  27.8  ...
# 8   MX17004  2010      5    tmax  29.9  31.3  28.6  27.2  29.6  27.8  ...
# 9   MX17004  2010      5    tmin  29.9  31.3  28.6  27.2  29.6  27.8  ...
# 10  MX17004  2010      6    tmax  29.9  31.3  28.6  27.2  29.6  27.8  ...
# 11  MX17004  2010      6    tmin  29.9  31.3  28.6  27.2  29.6  27.8  ...
# ...
